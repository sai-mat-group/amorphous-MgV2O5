# %%
import numpy as np
import os

def read_lammps_dump(filename):
    """Reads a LAMMPS trajectory file and extracts box dimensions and atomic positions."""
    with open(filename, "r") as f:
        lines = f.readlines()

    frames = []
    i = 0
    while i < len(lines):
        if "ITEM: TIMESTEP" in lines[i]:
            timestep = int(lines[i + 1].strip())
            i += 2
        elif "ITEM: BOX BOUNDS" in lines[i]:
            # Read box bounds
            x_bounds = list(map(float, lines[i + 1].strip().split()))
            y_bounds = list(map(float, lines[i + 2].strip().split()))
            z_bounds = list(map(float, lines[i + 3].strip().split()))
            i += 4
        elif "ITEM: ATOMS" in lines[i]:
            # Read atomic data
            atom_data = []
            headers = lines[i].strip().split()[2:]  # Extract column names
            i += 1
            while i < len(lines) and "ITEM:" not in lines[i]:
                atom_data.append(list(map(float, lines[i].strip().split())))
                i += 1

            atom_data = np.array(atom_data)
            frames.append({
                "timestep": timestep,
                "box": (x_bounds, y_bounds, z_bounds),
                "atoms": atom_data,
                "headers": headers,
            })
        else:
            i += 1

    return frames


def write_vasp_file(frame, filename, atom_type_map, updated_counts):
    """Writes a single frame to a VASP POSCAR/CONTCAR file."""
    x_bounds, y_bounds, z_bounds = frame["box"]
    atoms = frame["atoms"]
    headers = frame["headers"]

    # Extract lattice vectors from box bounds
    a = x_bounds[1] - x_bounds[0]
    b = y_bounds[1] - y_bounds[0]
    c = z_bounds[1] - z_bounds[0]
    lattice_vectors = np.array([
        [a, 0.0, 0.0],
        [0.0, b, 0.0],
        [0.0, 0.0, c],
    ])

    # Extract atom types and positions
    atom_types = atoms[:, headers.index("type")].astype(int)
    positions_cartesian = atoms[:, [headers.index("x"), headers.index("y"), headers.index("z")]]

    # Convert Cartesian coordinates to fractional
    inv_lattice = np.linalg.inv(lattice_vectors)
    positions_fractional = np.dot(positions_cartesian - [x_bounds[0], y_bounds[0], z_bounds[0]], inv_lattice)

    # Map numerical atom types to chemical symbols
    chemical_symbols = [atom_type_map[t] for t in atom_types]

    # Write VASP POSCAR/CONTCAR format with updated counts
    with open(filename, "w") as f:
        f.write(f"Generated from LAMMPS dump file\n")
        f.write(f"1.0\n")
        for vec in lattice_vectors:
            f.write(f"{vec[0]:.6f} {vec[1]:.6f} {vec[2]:.6f}\n")
        f.write(" ".join(updated_counts.keys()) + "\n")  # Chemical symbols
        f.write(" ".join(map(str, updated_counts.values())) + "\n")  # Updated counts
        f.write("Direct\n")
        
        for symbol in updated_counts.keys():
            count_to_write = updated_counts[symbol]
            symbol_positions = positions_fractional[np.array(chemical_symbols) == symbol]
            
            for pos in symbol_positions[:count_to_write]:
                f.write(f"{pos[0]:.6f} {pos[1]:.6f} {pos[2]:.6f}\n")


def convert_lammps_to_vasp(dump_file, output_dir, atom_type_map, updated_counts):
    """Converts all frames of a LAMMPS dump file to VASP POSCAR/CONTCAR files."""
    frames = read_lammps_dump(dump_file)

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i, frame in enumerate(frames):
        filename = os.path.join(output_dir, f"CONTCAR{i+1}")
        write_vasp_file(frame, filename, atom_type_map, updated_counts)
        print(f"Saved: {filename}")


# Example usage
dump_file = "dump.nb"
output_dir = "vasp_files_900"

# Define the mapping of numerical atom types to chemical symbols
atom_type_map = {
    1: "Mg",   # Atom type 1 -> Magnesium
    2: "V",    # Atom type 2 -> Oxygen
    3: "O",    # Atom type 3 -> Vanadium
}

# Define the updated counts for each chemical symbol (e.g., O -> 60)
updated_counts = {
    "Mg": 12,
    "V": 24,
    "O": 60,
}

convert_lammps_to_vasp(dump_file, output_dir, atom_type_map, updated_counts)
# Out:
# Saved: vasp_files_900\CONTCAR1
# Saved: vasp_files_900\CONTCAR2
# Saved: vasp_files_900\CONTCAR3
# Saved: vasp_files_900\CONTCAR4
# Saved: vasp_files_900\CONTCAR5
# Saved: vasp_files_900\CONTCAR6
# Saved: vasp_files_900\CONTCAR7
# Saved: vasp_files_900\CONTCAR8
# Saved: vasp_files_900\CONTCAR9
# Saved: vasp_files_900\CONTCAR10
# Saved: vasp_files_900\CONTCAR11
# Saved: vasp_files_900\CONTCAR12
# Saved: vasp_files_900\CONTCAR13
# Saved: vasp_files_900\CONTCAR14
# Saved: vasp_files_900\CONTCAR15
# Saved: vasp_files_900\CONTCAR16
# Saved: vasp_files_900\CONTCAR17
# Saved: vasp_files_900\CONTCAR18
# Saved: vasp_files_900\CONTCAR19
# Saved: vasp_files_900\CONTCAR20
# Saved: vasp_files_900\CONTCAR21
# Saved: vasp_files_900\CONTCAR22
# Saved: vasp_files_900\CONTCAR23
# Saved: vasp_files_900\CONTCAR24
# Saved: vasp_files_900\CONTCAR25
# Saved: vasp_files_900\CONTCAR26
# Saved: vasp_files_900\CONTCAR27
# Saved: vasp_files_900\CONTCAR28
# Saved: vasp_files_900\CONTCAR29
# Saved: vasp_files_900\CONTCAR30
# Saved: vasp_files_900\CONTCAR31
# Saved: vasp_files_900\CONTCAR32
# Saved: vasp_files_900\CONTCAR33
# Saved: vasp_files_900\CONTCAR34
# Saved: vasp_files_900\CONTCAR35
# Saved: vasp_files_900\CONTCAR36
# Saved: vasp_files_900\CONTCAR37
# Saved: vasp_files_900\CONTCAR38
# Saved: vasp_files_900\CONTCAR39
# Saved: vasp_files_900\CONTCAR40
# Saved: vasp_files_900\CONTCAR41
# Saved: vasp_files_900\CONTCAR42
# Saved: vasp_files_900\CONTCAR43
# Saved: vasp_files_900\CONTCAR44
# Saved: vasp_files_900\CONTCAR45
# Saved: vasp_files_900\CONTCAR46
# Saved: vasp_files_900\CONTCAR47
# Saved: vasp_files_900\CONTCAR48
# Saved: vasp_files_900\CONTCAR49
# Saved: vasp_files_900\CONTCAR50
# Saved: vasp_files_900\CONTCAR51
# Saved: vasp_files_900\CONTCAR52
# Saved: vasp_files_900\CONTCAR53
# Saved: vasp_files_900\CONTCAR54
# Saved: vasp_files_900\CONTCAR55
# Saved: vasp_files_900\CONTCAR56
# Saved: vasp_files_900\CONTCAR57
# Saved: vasp_files_900\CONTCAR58
# Saved: vasp_files_900\CONTCAR59
# Saved: vasp_files_900\CONTCAR60
# Saved: vasp_files_900\CONTCAR61
# Saved: vasp_files_900\CONTCAR62
# Saved: vasp_files_900\CONTCAR63
# Saved: vasp_files_900\CONTCAR64
# Saved: vasp_files_900\CONTCAR65
# Saved: vasp_files_900\CONTCAR66
# Saved: vasp_files_900\CONTCAR67
# Saved: vasp_files_900\CONTCAR68
# Saved: vasp_files_900\CONTCAR69
# Saved: vasp_files_900\CONTCAR70
# Saved: vasp_files_900\CONTCAR71
# Saved: vasp_files_900\CONTCAR72
# Saved: vasp_files_900\CONTCAR73
# Saved: vasp_files_900\CONTCAR74
# Saved: vasp_files_900\CONTCAR75
# Saved: vasp_files_900\CONTCAR76
# Saved: vasp_files_900\CONTCAR77
# Saved: vasp_files_900\CONTCAR78
# Saved: vasp_files_900\CONTCAR79
# Saved: vasp_files_900\CONTCAR80
# Saved: vasp_files_900\CONTCAR81
# Saved: vasp_files_900\CONTCAR82
# Saved: vasp_files_900\CONTCAR83
# Saved: vasp_files_900\CONTCAR84
# Saved: vasp_files_900\CONTCAR85
# Saved: vasp_files_900\CONTCAR86
# Saved: vasp_files_900\CONTCAR87
# Saved: vasp_files_900\CONTCAR88
# Saved: vasp_files_900\CONTCAR89
# Saved: vasp_files_900\CONTCAR90
# Saved: vasp_files_900\CONTCAR91
# Saved: vasp_files_900\CONTCAR92
# Saved: vasp_files_900\CONTCAR93
# Saved: vasp_files_900\CONTCAR94
# Saved: vasp_files_900\CONTCAR95
# Saved: vasp_files_900\CONTCAR96
# Saved: vasp_files_900\CONTCAR97
# Saved: vasp_files_900\CONTCAR98
# Saved: vasp_files_900\CONTCAR99
# Saved: vasp_files_900\CONTCAR100
# Saved: vasp_files_900\CONTCAR101
# Saved: vasp_files_900\CONTCAR102
# Saved: vasp_files_900\CONTCAR103
# Saved: vasp_files_900\CONTCAR104
# Saved: vasp_files_900\CONTCAR105
# Saved: vasp_files_900\CONTCAR106
# Saved: vasp_files_900\CONTCAR107
# Saved: vasp_files_900\CONTCAR108
# Saved: vasp_files_900\CONTCAR109
# Saved: vasp_files_900\CONTCAR110
# Saved: vasp_files_900\CONTCAR111
# Saved: vasp_files_900\CONTCAR112
# Saved: vasp_files_900\CONTCAR113
# Saved: vasp_files_900\CONTCAR114
# Saved: vasp_files_900\CONTCAR115
# Saved: vasp_files_900\CONTCAR116
# Saved: vasp_files_900\CONTCAR117
# Saved: vasp_files_900\CONTCAR118
# Saved: vasp_files_900\CONTCAR119
# Saved: vasp_files_900\CONTCAR120
# Saved: vasp_files_900\CONTCAR121
# Saved: vasp_files_900\CONTCAR122
# Saved: vasp_files_900\CONTCAR123
# Saved: vasp_files_900\CONTCAR124
# Saved: vasp_files_900\CONTCAR125
# Saved: vasp_files_900\CONTCAR126
# Saved: vasp_files_900\CONTCAR127
# Saved: vasp_files_900\CONTCAR128
# Saved: vasp_files_900\CONTCAR129
# Saved: vasp_files_900\CONTCAR130
# Saved: vasp_files_900\CONTCAR131
# Saved: vasp_files_900\CONTCAR132
# Saved: vasp_files_900\CONTCAR133
# Saved: vasp_files_900\CONTCAR134
# Saved: vasp_files_900\CONTCAR135
# Saved: vasp_files_900\CONTCAR136
# Saved: vasp_files_900\CONTCAR137
# Saved: vasp_files_900\CONTCAR138
# Saved: vasp_files_900\CONTCAR139
# Saved: vasp_files_900\CONTCAR140
# Saved: vasp_files_900\CONTCAR141
# Saved: vasp_files_900\CONTCAR142
# Saved: vasp_files_900\CONTCAR143
# Saved: vasp_files_900\CONTCAR144
# Saved: vasp_files_900\CONTCAR145
# Saved: vasp_files_900\CONTCAR146
# Saved: vasp_files_900\CONTCAR147
# Saved: vasp_files_900\CONTCAR148
# Saved: vasp_files_900\CONTCAR149
# Saved: vasp_files_900\CONTCAR150
# Saved: vasp_files_900\CONTCAR151
# Saved: vasp_files_900\CONTCAR152
# Saved: vasp_files_900\CONTCAR153
# Saved: vasp_files_900\CONTCAR154
# Saved: vasp_files_900\CONTCAR155
# Saved: vasp_files_900\CONTCAR156
# Saved: vasp_files_900\CONTCAR157
# Saved: vasp_files_900\CONTCAR158
# Saved: vasp_files_900\CONTCAR159
# Saved: vasp_files_900\CONTCAR160
# Saved: vasp_files_900\CONTCAR161
# Saved: vasp_files_900\CONTCAR162
# Saved: vasp_files_900\CONTCAR163
# Saved: vasp_files_900\CONTCAR164
# Saved: vasp_files_900\CONTCAR165
# Saved: vasp_files_900\CONTCAR166
# Saved: vasp_files_900\CONTCAR167
# Saved: vasp_files_900\CONTCAR168
# Saved: vasp_files_900\CONTCAR169
# Saved: vasp_files_900\CONTCAR170
# Saved: vasp_files_900\CONTCAR171
# Saved: vasp_files_900\CONTCAR172
# Saved: vasp_files_900\CONTCAR173
# Saved: vasp_files_900\CONTCAR174
# Saved: vasp_files_900\CONTCAR175
# Saved: vasp_files_900\CONTCAR176
# Saved: vasp_files_900\CONTCAR177
# Saved: vasp_files_900\CONTCAR178
# Saved: vasp_files_900\CONTCAR179
# Saved: vasp_files_900\CONTCAR180
# Saved: vasp_files_900\CONTCAR181
# Saved: vasp_files_900\CONTCAR182
# Saved: vasp_files_900\CONTCAR183
# Saved: vasp_files_900\CONTCAR184
# Saved: vasp_files_900\CONTCAR185
# Saved: vasp_files_900\CONTCAR186
# Saved: vasp_files_900\CONTCAR187
# Saved: vasp_files_900\CONTCAR188
# Saved: vasp_files_900\CONTCAR189
# Saved: vasp_files_900\CONTCAR190
# Saved: vasp_files_900\CONTCAR191
# Saved: vasp_files_900\CONTCAR192
# Saved: vasp_files_900\CONTCAR193
# Saved: vasp_files_900\CONTCAR194
# Saved: vasp_files_900\CONTCAR195
# Saved: vasp_files_900\CONTCAR196
# Saved: vasp_files_900\CONTCAR197
# Saved: vasp_files_900\CONTCAR198
# Saved: vasp_files_900\CONTCAR199
# Saved: vasp_files_900\CONTCAR200
# Saved: vasp_files_900\CONTCAR201
# Saved: vasp_files_900\CONTCAR202
# Saved: vasp_files_900\CONTCAR203
# Saved: vasp_files_900\CONTCAR204
# Saved: vasp_files_900\CONTCAR205
# Saved: vasp_files_900\CONTCAR206
# Saved: vasp_files_900\CONTCAR207
# Saved: vasp_files_900\CONTCAR208
# Saved: vasp_files_900\CONTCAR209
# Saved: vasp_files_900\CONTCAR210
# Saved: vasp_files_900\CONTCAR211
# Saved: vasp_files_900\CONTCAR212
# Saved: vasp_files_900\CONTCAR213
# Saved: vasp_files_900\CONTCAR214
# Saved: vasp_files_900\CONTCAR215
# Saved: vasp_files_900\CONTCAR216
# Saved: vasp_files_900\CONTCAR217
# Saved: vasp_files_900\CONTCAR218
# Saved: vasp_files_900\CONTCAR219
# Saved: vasp_files_900\CONTCAR220
# Saved: vasp_files_900\CONTCAR221
# Saved: vasp_files_900\CONTCAR222
# Saved: vasp_files_900\CONTCAR223
# Saved: vasp_files_900\CONTCAR224
# Saved: vasp_files_900\CONTCAR225
# Saved: vasp_files_900\CONTCAR226
# Saved: vasp_files_900\CONTCAR227
# Saved: vasp_files_900\CONTCAR228
# Saved: vasp_files_900\CONTCAR229
# Saved: vasp_files_900\CONTCAR230
# Saved: vasp_files_900\CONTCAR231
# Saved: vasp_files_900\CONTCAR232
# Saved: vasp_files_900\CONTCAR233
# Saved: vasp_files_900\CONTCAR234
# Saved: vasp_files_900\CONTCAR235
# Saved: vasp_files_900\CONTCAR236
# Saved: vasp_files_900\CONTCAR237
# Saved: vasp_files_900\CONTCAR238
# Saved: vasp_files_900\CONTCAR239
# Saved: vasp_files_900\CONTCAR240
# Saved: vasp_files_900\CONTCAR241
# Saved: vasp_files_900\CONTCAR242
# Saved: vasp_files_900\CONTCAR243
# Saved: vasp_files_900\CONTCAR244
# Saved: vasp_files_900\CONTCAR245
# Saved: vasp_files_900\CONTCAR246
# Saved: vasp_files_900\CONTCAR247
# Saved: vasp_files_900\CONTCAR248
# Saved: vasp_files_900\CONTCAR249
# Saved: vasp_files_900\CONTCAR250
# Saved: vasp_files_900\CONTCAR251
# Saved: vasp_files_900\CONTCAR252
# Saved: vasp_files_900\CONTCAR253
# Saved: vasp_files_900\CONTCAR254
# Saved: vasp_files_900\CONTCAR255
# Saved: vasp_files_900\CONTCAR256
# Saved: vasp_files_900\CONTCAR257
# Saved: vasp_files_900\CONTCAR258
# Saved: vasp_files_900\CONTCAR259
# Saved: vasp_files_900\CONTCAR260
# Saved: vasp_files_900\CONTCAR261
# Saved: vasp_files_900\CONTCAR262
# Saved: vasp_files_900\CONTCAR263
# Saved: vasp_files_900\CONTCAR264
# Saved: vasp_files_900\CONTCAR265
# Saved: vasp_files_900\CONTCAR266
# Saved: vasp_files_900\CONTCAR267
# Saved: vasp_files_900\CONTCAR268
# Saved: vasp_files_900\CONTCAR269
# Saved: vasp_files_900\CONTCAR270
# Saved: vasp_files_900\CONTCAR271
# Saved: vasp_files_900\CONTCAR272
# Saved: vasp_files_900\CONTCAR273
# Saved: vasp_files_900\CONTCAR274
# Saved: vasp_files_900\CONTCAR275
# Saved: vasp_files_900\CONTCAR276
# Saved: vasp_files_900\CONTCAR277
# Saved: vasp_files_900\CONTCAR278
# Saved: vasp_files_900\CONTCAR279
# Saved: vasp_files_900\CONTCAR280
# Saved: vasp_files_900\CONTCAR281
# Saved: vasp_files_900\CONTCAR282
# Saved: vasp_files_900\CONTCAR283
# Saved: vasp_files_900\CONTCAR284
# Saved: vasp_files_900\CONTCAR285
# Saved: vasp_files_900\CONTCAR286
# Saved: vasp_files_900\CONTCAR287
# Saved: vasp_files_900\CONTCAR288
# Saved: vasp_files_900\CONTCAR289
# Saved: vasp_files_900\CONTCAR290
# Saved: vasp_files_900\CONTCAR291
# Saved: vasp_files_900\CONTCAR292
# Saved: vasp_files_900\CONTCAR293
# Saved: vasp_files_900\CONTCAR294
# Saved: vasp_files_900\CONTCAR295
# Saved: vasp_files_900\CONTCAR296
# Saved: vasp_files_900\CONTCAR297
# Saved: vasp_files_900\CONTCAR298
# Saved: vasp_files_900\CONTCAR299
# Saved: vasp_files_900\CONTCAR300
# Saved: vasp_files_900\CONTCAR301
# Saved: vasp_files_900\CONTCAR302
# Saved: vasp_files_900\CONTCAR303
# Saved: vasp_files_900\CONTCAR304
# Saved: vasp_files_900\CONTCAR305
# Saved: vasp_files_900\CONTCAR306
# Saved: vasp_files_900\CONTCAR307
# Saved: vasp_files_900\CONTCAR308
# Saved: vasp_files_900\CONTCAR309
# Saved: vasp_files_900\CONTCAR310
# Saved: vasp_files_900\CONTCAR311
# Saved: vasp_files_900\CONTCAR312
# Saved: vasp_files_900\CONTCAR313
# Saved: vasp_files_900\CONTCAR314
# Saved: vasp_files_900\CONTCAR315
# Saved: vasp_files_900\CONTCAR316
# Saved: vasp_files_900\CONTCAR317
# Saved: vasp_files_900\CONTCAR318
# Saved: vasp_files_900\CONTCAR319
# Saved: vasp_files_900\CONTCAR320
# Saved: vasp_files_900\CONTCAR321
# Saved: vasp_files_900\CONTCAR322
# Saved: vasp_files_900\CONTCAR323
# Saved: vasp_files_900\CONTCAR324
# Saved: vasp_files_900\CONTCAR325
# Saved: vasp_files_900\CONTCAR326
# Saved: vasp_files_900\CONTCAR327
# Saved: vasp_files_900\CONTCAR328
# Saved: vasp_files_900\CONTCAR329
# Saved: vasp_files_900\CONTCAR330
# Saved: vasp_files_900\CONTCAR331
# Saved: vasp_files_900\CONTCAR332
# Saved: vasp_files_900\CONTCAR333
# Saved: vasp_files_900\CONTCAR334
# Saved: vasp_files_900\CONTCAR335
# Saved: vasp_files_900\CONTCAR336
# Saved: vasp_files_900\CONTCAR337
# Saved: vasp_files_900\CONTCAR338
# Saved: vasp_files_900\CONTCAR339
# Saved: vasp_files_900\CONTCAR340
# Saved: vasp_files_900\CONTCAR341
# Saved: vasp_files_900\CONTCAR342
# Saved: vasp_files_900\CONTCAR343
# Saved: vasp_files_900\CONTCAR344
# Saved: vasp_files_900\CONTCAR345
# Saved: vasp_files_900\CONTCAR346
# Saved: vasp_files_900\CONTCAR347
# Saved: vasp_files_900\CONTCAR348
# Saved: vasp_files_900\CONTCAR349
# Saved: vasp_files_900\CONTCAR350
# Saved: vasp_files_900\CONTCAR351
# Saved: vasp_files_900\CONTCAR352
# Saved: vasp_files_900\CONTCAR353
# Saved: vasp_files_900\CONTCAR354
# Saved: vasp_files_900\CONTCAR355
# Saved: vasp_files_900\CONTCAR356
# Saved: vasp_files_900\CONTCAR357
# Saved: vasp_files_900\CONTCAR358
# Saved: vasp_files_900\CONTCAR359
# Saved: vasp_files_900\CONTCAR360
# Saved: vasp_files_900\CONTCAR361
# Saved: vasp_files_900\CONTCAR362
# Saved: vasp_files_900\CONTCAR363
# Saved: vasp_files_900\CONTCAR364
# Saved: vasp_files_900\CONTCAR365
# Saved: vasp_files_900\CONTCAR366
# Saved: vasp_files_900\CONTCAR367
# Saved: vasp_files_900\CONTCAR368
# Saved: vasp_files_900\CONTCAR369
# Saved: vasp_files_900\CONTCAR370
# Saved: vasp_files_900\CONTCAR371
# Saved: vasp_files_900\CONTCAR372
# Saved: vasp_files_900\CONTCAR373
# Saved: vasp_files_900\CONTCAR374
# Saved: vasp_files_900\CONTCAR375
# Saved: vasp_files_900\CONTCAR376
# Saved: vasp_files_900\CONTCAR377
# Saved: vasp_files_900\CONTCAR378
# Saved: vasp_files_900\CONTCAR379
# Saved: vasp_files_900\CONTCAR380
# Saved: vasp_files_900\CONTCAR381
# Saved: vasp_files_900\CONTCAR382
# Saved: vasp_files_900\CONTCAR383
# Saved: vasp_files_900\CONTCAR384
# Saved: vasp_files_900\CONTCAR385
# Saved: vasp_files_900\CONTCAR386
# Saved: vasp_files_900\CONTCAR387
# Saved: vasp_files_900\CONTCAR388
# Saved: vasp_files_900\CONTCAR389
# Saved: vasp_files_900\CONTCAR390
# Saved: vasp_files_900\CONTCAR391
# Saved: vasp_files_900\CONTCAR392
# Saved: vasp_files_900\CONTCAR393
# Saved: vasp_files_900\CONTCAR394
# Saved: vasp_files_900\CONTCAR395
# Saved: vasp_files_900\CONTCAR396
# Saved: vasp_files_900\CONTCAR397
# Saved: vasp_files_900\CONTCAR398
# Saved: vasp_files_900\CONTCAR399
# Saved: vasp_files_900\CONTCAR400
# Saved: vasp_files_900\CONTCAR401
# Saved: vasp_files_900\CONTCAR402
# Saved: vasp_files_900\CONTCAR403
# Saved: vasp_files_900\CONTCAR404
# Saved: vasp_files_900\CONTCAR405
# Saved: vasp_files_900\CONTCAR406
# Saved: vasp_files_900\CONTCAR407
# Saved: vasp_files_900\CONTCAR408
# Saved: vasp_files_900\CONTCAR409
# Saved: vasp_files_900\CONTCAR410
# Saved: vasp_files_900\CONTCAR411
# Saved: vasp_files_900\CONTCAR412
# Saved: vasp_files_900\CONTCAR413
# Saved: vasp_files_900\CONTCAR414
# Saved: vasp_files_900\CONTCAR415
# Saved: vasp_files_900\CONTCAR416
# Saved: vasp_files_900\CONTCAR417
# Saved: vasp_files_900\CONTCAR418
# Saved: vasp_files_900\CONTCAR419
# Saved: vasp_files_900\CONTCAR420
# Saved: vasp_files_900\CONTCAR421
# Saved: vasp_files_900\CONTCAR422
# Saved: vasp_files_900\CONTCAR423
# Saved: vasp_files_900\CONTCAR424
# Saved: vasp_files_900\CONTCAR425
# Saved: vasp_files_900\CONTCAR426
# Saved: vasp_files_900\CONTCAR427
# Saved: vasp_files_900\CONTCAR428
# Saved: vasp_files_900\CONTCAR429
# Saved: vasp_files_900\CONTCAR430
# Saved: vasp_files_900\CONTCAR431
# Saved: vasp_files_900\CONTCAR432
# Saved: vasp_files_900\CONTCAR433
# Saved: vasp_files_900\CONTCAR434
# Saved: vasp_files_900\CONTCAR435
# Saved: vasp_files_900\CONTCAR436
# Saved: vasp_files_900\CONTCAR437
# Saved: vasp_files_900\CONTCAR438
# Saved: vasp_files_900\CONTCAR439
# Saved: vasp_files_900\CONTCAR440
# Saved: vasp_files_900\CONTCAR441
# Saved: vasp_files_900\CONTCAR442
# Saved: vasp_files_900\CONTCAR443
# Saved: vasp_files_900\CONTCAR444
# Saved: vasp_files_900\CONTCAR445
# Saved: vasp_files_900\CONTCAR446
# Saved: vasp_files_900\CONTCAR447
# Saved: vasp_files_900\CONTCAR448
# Saved: vasp_files_900\CONTCAR449
# Saved: vasp_files_900\CONTCAR450
# Saved: vasp_files_900\CONTCAR451
# Saved: vasp_files_900\CONTCAR452
# Saved: vasp_files_900\CONTCAR453
# Saved: vasp_files_900\CONTCAR454
# Saved: vasp_files_900\CONTCAR455
# Saved: vasp_files_900\CONTCAR456
# Saved: vasp_files_900\CONTCAR457
# Saved: vasp_files_900\CONTCAR458
# Saved: vasp_files_900\CONTCAR459
# Saved: vasp_files_900\CONTCAR460
# Saved: vasp_files_900\CONTCAR461
# Saved: vasp_files_900\CONTCAR462
# Saved: vasp_files_900\CONTCAR463
# Saved: vasp_files_900\CONTCAR464
# Saved: vasp_files_900\CONTCAR465
# Saved: vasp_files_900\CONTCAR466
# Saved: vasp_files_900\CONTCAR467
# Saved: vasp_files_900\CONTCAR468
# Saved: vasp_files_900\CONTCAR469
# Saved: vasp_files_900\CONTCAR470
# Saved: vasp_files_900\CONTCAR471
# Saved: vasp_files_900\CONTCAR472
# Saved: vasp_files_900\CONTCAR473
# Saved: vasp_files_900\CONTCAR474
# Saved: vasp_files_900\CONTCAR475
# Saved: vasp_files_900\CONTCAR476
# Saved: vasp_files_900\CONTCAR477
# Saved: vasp_files_900\CONTCAR478
# Saved: vasp_files_900\CONTCAR479
# Saved: vasp_files_900\CONTCAR480
# Saved: vasp_files_900\CONTCAR481
# Saved: vasp_files_900\CONTCAR482
# Saved: vasp_files_900\CONTCAR483
# Saved: vasp_files_900\CONTCAR484
# Saved: vasp_files_900\CONTCAR485
# Saved: vasp_files_900\CONTCAR486
# Saved: vasp_files_900\CONTCAR487
# Saved: vasp_files_900\CONTCAR488
# Saved: vasp_files_900\CONTCAR489
# Saved: vasp_files_900\CONTCAR490
# Saved: vasp_files_900\CONTCAR491
# Saved: vasp_files_900\CONTCAR492
# Saved: vasp_files_900\CONTCAR493
# Saved: vasp_files_900\CONTCAR494
# Saved: vasp_files_900\CONTCAR495
# Saved: vasp_files_900\CONTCAR496
# Saved: vasp_files_900\CONTCAR497
# Saved: vasp_files_900\CONTCAR498
# Saved: vasp_files_900\CONTCAR499
# Saved: vasp_files_900\CONTCAR500
# Saved: vasp_files_900\CONTCAR501
# Saved: vasp_files_900\CONTCAR502
# Saved: vasp_files_900\CONTCAR503
# Saved: vasp_files_900\CONTCAR504
# Saved: vasp_files_900\CONTCAR505
# Saved: vasp_files_900\CONTCAR506
# Saved: vasp_files_900\CONTCAR507
# Saved: vasp_files_900\CONTCAR508
# Saved: vasp_files_900\CONTCAR509
# Saved: vasp_files_900\CONTCAR510
# Saved: vasp_files_900\CONTCAR511
# Saved: vasp_files_900\CONTCAR512
# Saved: vasp_files_900\CONTCAR513
# Saved: vasp_files_900\CONTCAR514
# Saved: vasp_files_900\CONTCAR515
# Saved: vasp_files_900\CONTCAR516
# Saved: vasp_files_900\CONTCAR517
# Saved: vasp_files_900\CONTCAR518
# Saved: vasp_files_900\CONTCAR519
# Saved: vasp_files_900\CONTCAR520
# Saved: vasp_files_900\CONTCAR521
# Saved: vasp_files_900\CONTCAR522
# Saved: vasp_files_900\CONTCAR523
# Saved: vasp_files_900\CONTCAR524
# Saved: vasp_files_900\CONTCAR525
# Saved: vasp_files_900\CONTCAR526
# Saved: vasp_files_900\CONTCAR527
# Saved: vasp_files_900\CONTCAR528
# Saved: vasp_files_900\CONTCAR529
# Saved: vasp_files_900\CONTCAR530
# Saved: vasp_files_900\CONTCAR531
# Saved: vasp_files_900\CONTCAR532
# Saved: vasp_files_900\CONTCAR533
# Saved: vasp_files_900\CONTCAR534
# Saved: vasp_files_900\CONTCAR535
# Saved: vasp_files_900\CONTCAR536
# Saved: vasp_files_900\CONTCAR537
# Saved: vasp_files_900\CONTCAR538
# Saved: vasp_files_900\CONTCAR539
# Saved: vasp_files_900\CONTCAR540
# Saved: vasp_files_900\CONTCAR541
# Saved: vasp_files_900\CONTCAR542
# Saved: vasp_files_900\CONTCAR543
# Saved: vasp_files_900\CONTCAR544
# Saved: vasp_files_900\CONTCAR545
# Saved: vasp_files_900\CONTCAR546
# Saved: vasp_files_900\CONTCAR547
# Saved: vasp_files_900\CONTCAR548
# Saved: vasp_files_900\CONTCAR549
# Saved: vasp_files_900\CONTCAR550
# Saved: vasp_files_900\CONTCAR551
# Saved: vasp_files_900\CONTCAR552
# Saved: vasp_files_900\CONTCAR553
# Saved: vasp_files_900\CONTCAR554
# Saved: vasp_files_900\CONTCAR555
# Saved: vasp_files_900\CONTCAR556
# Saved: vasp_files_900\CONTCAR557
# Saved: vasp_files_900\CONTCAR558
# Saved: vasp_files_900\CONTCAR559
# Saved: vasp_files_900\CONTCAR560
# Saved: vasp_files_900\CONTCAR561
# Saved: vasp_files_900\CONTCAR562
# Saved: vasp_files_900\CONTCAR563
# Saved: vasp_files_900\CONTCAR564
# Saved: vasp_files_900\CONTCAR565
# Saved: vasp_files_900\CONTCAR566
# Saved: vasp_files_900\CONTCAR567
# Saved: vasp_files_900\CONTCAR568
# Saved: vasp_files_900\CONTCAR569
# Saved: vasp_files_900\CONTCAR570
# Saved: vasp_files_900\CONTCAR571
# Saved: vasp_files_900\CONTCAR572
# Saved: vasp_files_900\CONTCAR573
# Saved: vasp_files_900\CONTCAR574
# Saved: vasp_files_900\CONTCAR575
# Saved: vasp_files_900\CONTCAR576
# Saved: vasp_files_900\CONTCAR577
# Saved: vasp_files_900\CONTCAR578
# Saved: vasp_files_900\CONTCAR579
# Saved: vasp_files_900\CONTCAR580
# Saved: vasp_files_900\CONTCAR581
# Saved: vasp_files_900\CONTCAR582
# Saved: vasp_files_900\CONTCAR583
# Saved: vasp_files_900\CONTCAR584
# Saved: vasp_files_900\CONTCAR585
# Saved: vasp_files_900\CONTCAR586
# Saved: vasp_files_900\CONTCAR587
# Saved: vasp_files_900\CONTCAR588
# Saved: vasp_files_900\CONTCAR589
# Saved: vasp_files_900\CONTCAR590
# Saved: vasp_files_900\CONTCAR591
# Saved: vasp_files_900\CONTCAR592
# Saved: vasp_files_900\CONTCAR593
# Saved: vasp_files_900\CONTCAR594
# Saved: vasp_files_900\CONTCAR595
# Saved: vasp_files_900\CONTCAR596
# Saved: vasp_files_900\CONTCAR597
# Saved: vasp_files_900\CONTCAR598
# Saved: vasp_files_900\CONTCAR599
# Saved: vasp_files_900\CONTCAR600
# Saved: vasp_files_900\CONTCAR601
# Saved: vasp_files_900\CONTCAR602
# Saved: vasp_files_900\CONTCAR603
# Saved: vasp_files_900\CONTCAR604
# Saved: vasp_files_900\CONTCAR605
# Saved: vasp_files_900\CONTCAR606
# Saved: vasp_files_900\CONTCAR607
# Saved: vasp_files_900\CONTCAR608
# Saved: vasp_files_900\CONTCAR609
# Saved: vasp_files_900\CONTCAR610
# Saved: vasp_files_900\CONTCAR611
# Saved: vasp_files_900\CONTCAR612
# Saved: vasp_files_900\CONTCAR613
# Saved: vasp_files_900\CONTCAR614
# Saved: vasp_files_900\CONTCAR615
# Saved: vasp_files_900\CONTCAR616
# Saved: vasp_files_900\CONTCAR617
# Saved: vasp_files_900\CONTCAR618
# Saved: vasp_files_900\CONTCAR619
# Saved: vasp_files_900\CONTCAR620
# Saved: vasp_files_900\CONTCAR621
# Saved: vasp_files_900\CONTCAR622
# Saved: vasp_files_900\CONTCAR623
# Saved: vasp_files_900\CONTCAR624
# Saved: vasp_files_900\CONTCAR625
# Saved: vasp_files_900\CONTCAR626
# Saved: vasp_files_900\CONTCAR627
# Saved: vasp_files_900\CONTCAR628
# Saved: vasp_files_900\CONTCAR629
# Saved: vasp_files_900\CONTCAR630
# Saved: vasp_files_900\CONTCAR631
# Saved: vasp_files_900\CONTCAR632
# Saved: vasp_files_900\CONTCAR633
# Saved: vasp_files_900\CONTCAR634
# Saved: vasp_files_900\CONTCAR635
# Saved: vasp_files_900\CONTCAR636
# Saved: vasp_files_900\CONTCAR637
# Saved: vasp_files_900\CONTCAR638
# Saved: vasp_files_900\CONTCAR639
# Saved: vasp_files_900\CONTCAR640
# Saved: vasp_files_900\CONTCAR641
# Saved: vasp_files_900\CONTCAR642
# Saved: vasp_files_900\CONTCAR643
# Saved: vasp_files_900\CONTCAR644
# Saved: vasp_files_900\CONTCAR645
# Saved: vasp_files_900\CONTCAR646
# Saved: vasp_files_900\CONTCAR647
# Saved: vasp_files_900\CONTCAR648
# Saved: vasp_files_900\CONTCAR649
# Saved: vasp_files_900\CONTCAR650
# Saved: vasp_files_900\CONTCAR651
# Saved: vasp_files_900\CONTCAR652
# Saved: vasp_files_900\CONTCAR653
# Saved: vasp_files_900\CONTCAR654
# Saved: vasp_files_900\CONTCAR655
# Saved: vasp_files_900\CONTCAR656
# Saved: vasp_files_900\CONTCAR657
# Saved: vasp_files_900\CONTCAR658
# Saved: vasp_files_900\CONTCAR659
# Saved: vasp_files_900\CONTCAR660
# Saved: vasp_files_900\CONTCAR661
# Saved: vasp_files_900\CONTCAR662
# Saved: vasp_files_900\CONTCAR663
# Saved: vasp_files_900\CONTCAR664
# Saved: vasp_files_900\CONTCAR665
# Saved: vasp_files_900\CONTCAR666
# Saved: vasp_files_900\CONTCAR667
# Saved: vasp_files_900\CONTCAR668
# Saved: vasp_files_900\CONTCAR669
# Saved: vasp_files_900\CONTCAR670
# Saved: vasp_files_900\CONTCAR671
# Saved: vasp_files_900\CONTCAR672
# Saved: vasp_files_900\CONTCAR673
# Saved: vasp_files_900\CONTCAR674
# Saved: vasp_files_900\CONTCAR675
# Saved: vasp_files_900\CONTCAR676
# Saved: vasp_files_900\CONTCAR677
# Saved: vasp_files_900\CONTCAR678
# Saved: vasp_files_900\CONTCAR679
# Saved: vasp_files_900\CONTCAR680
# Saved: vasp_files_900\CONTCAR681
# Saved: vasp_files_900\CONTCAR682
# Saved: vasp_files_900\CONTCAR683
# Saved: vasp_files_900\CONTCAR684
# Saved: vasp_files_900\CONTCAR685
# Saved: vasp_files_900\CONTCAR686
# Saved: vasp_files_900\CONTCAR687
# Saved: vasp_files_900\CONTCAR688
# Saved: vasp_files_900\CONTCAR689
# Saved: vasp_files_900\CONTCAR690
# Saved: vasp_files_900\CONTCAR691
# Saved: vasp_files_900\CONTCAR692
# Saved: vasp_files_900\CONTCAR693
# Saved: vasp_files_900\CONTCAR694
# Saved: vasp_files_900\CONTCAR695
# Saved: vasp_files_900\CONTCAR696
# Saved: vasp_files_900\CONTCAR697
# Saved: vasp_files_900\CONTCAR698
# Saved: vasp_files_900\CONTCAR699
# Saved: vasp_files_900\CONTCAR700
# Saved: vasp_files_900\CONTCAR701
# Saved: vasp_files_900\CONTCAR702
# Saved: vasp_files_900\CONTCAR703
# Saved: vasp_files_900\CONTCAR704
# Saved: vasp_files_900\CONTCAR705
# Saved: vasp_files_900\CONTCAR706
# Saved: vasp_files_900\CONTCAR707
# Saved: vasp_files_900\CONTCAR708
# Saved: vasp_files_900\CONTCAR709
# Saved: vasp_files_900\CONTCAR710
# Saved: vasp_files_900\CONTCAR711
# Saved: vasp_files_900\CONTCAR712
# Saved: vasp_files_900\CONTCAR713
# Saved: vasp_files_900\CONTCAR714
# Saved: vasp_files_900\CONTCAR715
# Saved: vasp_files_900\CONTCAR716
# Saved: vasp_files_900\CONTCAR717
# Saved: vasp_files_900\CONTCAR718
# Saved: vasp_files_900\CONTCAR719
# Saved: vasp_files_900\CONTCAR720
# Saved: vasp_files_900\CONTCAR721
# Saved: vasp_files_900\CONTCAR722
# Saved: vasp_files_900\CONTCAR723
# Saved: vasp_files_900\CONTCAR724
# Saved: vasp_files_900\CONTCAR725
# Saved: vasp_files_900\CONTCAR726
# Saved: vasp_files_900\CONTCAR727
# Saved: vasp_files_900\CONTCAR728
# Saved: vasp_files_900\CONTCAR729
# Saved: vasp_files_900\CONTCAR730
# Saved: vasp_files_900\CONTCAR731
# Saved: vasp_files_900\CONTCAR732
# Saved: vasp_files_900\CONTCAR733
# Saved: vasp_files_900\CONTCAR734
# Saved: vasp_files_900\CONTCAR735
# Saved: vasp_files_900\CONTCAR736
# Saved: vasp_files_900\CONTCAR737
# Saved: vasp_files_900\CONTCAR738
# Saved: vasp_files_900\CONTCAR739
# Saved: vasp_files_900\CONTCAR740
# Saved: vasp_files_900\CONTCAR741
# Saved: vasp_files_900\CONTCAR742
# Saved: vasp_files_900\CONTCAR743
# Saved: vasp_files_900\CONTCAR744
# Saved: vasp_files_900\CONTCAR745
# Saved: vasp_files_900\CONTCAR746
# Saved: vasp_files_900\CONTCAR747
# Saved: vasp_files_900\CONTCAR748
# Saved: vasp_files_900\CONTCAR749
# Saved: vasp_files_900\CONTCAR750
# Saved: vasp_files_900\CONTCAR751
# Saved: vasp_files_900\CONTCAR752
# Saved: vasp_files_900\CONTCAR753
# Saved: vasp_files_900\CONTCAR754
# Saved: vasp_files_900\CONTCAR755
# Saved: vasp_files_900\CONTCAR756
# Saved: vasp_files_900\CONTCAR757
# Saved: vasp_files_900\CONTCAR758
# Saved: vasp_files_900\CONTCAR759
# Saved: vasp_files_900\CONTCAR760
# Saved: vasp_files_900\CONTCAR761
# Saved: vasp_files_900\CONTCAR762
# Saved: vasp_files_900\CONTCAR763
# Saved: vasp_files_900\CONTCAR764
# Saved: vasp_files_900\CONTCAR765
# Saved: vasp_files_900\CONTCAR766
# Saved: vasp_files_900\CONTCAR767
# Saved: vasp_files_900\CONTCAR768
# Saved: vasp_files_900\CONTCAR769
# Saved: vasp_files_900\CONTCAR770
# Saved: vasp_files_900\CONTCAR771
# Saved: vasp_files_900\CONTCAR772
# Saved: vasp_files_900\CONTCAR773
# Saved: vasp_files_900\CONTCAR774
# Saved: vasp_files_900\CONTCAR775
# Saved: vasp_files_900\CONTCAR776
# Saved: vasp_files_900\CONTCAR777
# Saved: vasp_files_900\CONTCAR778
# Saved: vasp_files_900\CONTCAR779
# Saved: vasp_files_900\CONTCAR780
# Saved: vasp_files_900\CONTCAR781
# Saved: vasp_files_900\CONTCAR782
# Saved: vasp_files_900\CONTCAR783
# Saved: vasp_files_900\CONTCAR784
# Saved: vasp_files_900\CONTCAR785
# Saved: vasp_files_900\CONTCAR786
# Saved: vasp_files_900\CONTCAR787
# Saved: vasp_files_900\CONTCAR788
# Saved: vasp_files_900\CONTCAR789
# Saved: vasp_files_900\CONTCAR790
# Saved: vasp_files_900\CONTCAR791
# Saved: vasp_files_900\CONTCAR792
# Saved: vasp_files_900\CONTCAR793
# Saved: vasp_files_900\CONTCAR794
# Saved: vasp_files_900\CONTCAR795
# Saved: vasp_files_900\CONTCAR796
# Saved: vasp_files_900\CONTCAR797
# Saved: vasp_files_900\CONTCAR798
# Saved: vasp_files_900\CONTCAR799
# Saved: vasp_files_900\CONTCAR800
# Saved: vasp_files_900\CONTCAR801
# Saved: vasp_files_900\CONTCAR802
# Saved: vasp_files_900\CONTCAR803
# Saved: vasp_files_900\CONTCAR804
# Saved: vasp_files_900\CONTCAR805
# Saved: vasp_files_900\CONTCAR806
# Saved: vasp_files_900\CONTCAR807
# Saved: vasp_files_900\CONTCAR808
# Saved: vasp_files_900\CONTCAR809
# Saved: vasp_files_900\CONTCAR810
# Saved: vasp_files_900\CONTCAR811
# Saved: vasp_files_900\CONTCAR812
# Saved: vasp_files_900\CONTCAR813
# Saved: vasp_files_900\CONTCAR814
# Saved: vasp_files_900\CONTCAR815
# Saved: vasp_files_900\CONTCAR816
# Saved: vasp_files_900\CONTCAR817
# Saved: vasp_files_900\CONTCAR818
# Saved: vasp_files_900\CONTCAR819
# Saved: vasp_files_900\CONTCAR820
# Saved: vasp_files_900\CONTCAR821
# Saved: vasp_files_900\CONTCAR822
# Saved: vasp_files_900\CONTCAR823
# Saved: vasp_files_900\CONTCAR824
# Saved: vasp_files_900\CONTCAR825
# Saved: vasp_files_900\CONTCAR826
# Saved: vasp_files_900\CONTCAR827
# Saved: vasp_files_900\CONTCAR828
# Saved: vasp_files_900\CONTCAR829
# Saved: vasp_files_900\CONTCAR830
# Saved: vasp_files_900\CONTCAR831
# Saved: vasp_files_900\CONTCAR832
# Saved: vasp_files_900\CONTCAR833
# Saved: vasp_files_900\CONTCAR834
# Saved: vasp_files_900\CONTCAR835
# Saved: vasp_files_900\CONTCAR836
# Saved: vasp_files_900\CONTCAR837
# Saved: vasp_files_900\CONTCAR838
# Saved: vasp_files_900\CONTCAR839
# Saved: vasp_files_900\CONTCAR840
# Saved: vasp_files_900\CONTCAR841
# Saved: vasp_files_900\CONTCAR842
# Saved: vasp_files_900\CONTCAR843
# Saved: vasp_files_900\CONTCAR844
# Saved: vasp_files_900\CONTCAR845
# Saved: vasp_files_900\CONTCAR846
# Saved: vasp_files_900\CONTCAR847
# Saved: vasp_files_900\CONTCAR848
# Saved: vasp_files_900\CONTCAR849
# Saved: vasp_files_900\CONTCAR850
# Saved: vasp_files_900\CONTCAR851
# Saved: vasp_files_900\CONTCAR852
# Saved: vasp_files_900\CONTCAR853
# Saved: vasp_files_900\CONTCAR854
# Saved: vasp_files_900\CONTCAR855
# Saved: vasp_files_900\CONTCAR856
# Saved: vasp_files_900\CONTCAR857
# Saved: vasp_files_900\CONTCAR858
# Saved: vasp_files_900\CONTCAR859
# Saved: vasp_files_900\CONTCAR860
# Saved: vasp_files_900\CONTCAR861
# Saved: vasp_files_900\CONTCAR862
# Saved: vasp_files_900\CONTCAR863
# Saved: vasp_files_900\CONTCAR864
# Saved: vasp_files_900\CONTCAR865
# Saved: vasp_files_900\CONTCAR866
# Saved: vasp_files_900\CONTCAR867
# Saved: vasp_files_900\CONTCAR868
# Saved: vasp_files_900\CONTCAR869
# Saved: vasp_files_900\CONTCAR870
# Saved: vasp_files_900\CONTCAR871
# Saved: vasp_files_900\CONTCAR872
# Saved: vasp_files_900\CONTCAR873
# Saved: vasp_files_900\CONTCAR874
# Saved: vasp_files_900\CONTCAR875
# Saved: vasp_files_900\CONTCAR876
# Saved: vasp_files_900\CONTCAR877
# Saved: vasp_files_900\CONTCAR878
# Saved: vasp_files_900\CONTCAR879
# Saved: vasp_files_900\CONTCAR880
# Saved: vasp_files_900\CONTCAR881
# Saved: vasp_files_900\CONTCAR882
# Saved: vasp_files_900\CONTCAR883
# Saved: vasp_files_900\CONTCAR884
# Saved: vasp_files_900\CONTCAR885
# Saved: vasp_files_900\CONTCAR886
# Saved: vasp_files_900\CONTCAR887
# Saved: vasp_files_900\CONTCAR888
# Saved: vasp_files_900\CONTCAR889
# Saved: vasp_files_900\CONTCAR890
# Saved: vasp_files_900\CONTCAR891
# Saved: vasp_files_900\CONTCAR892
# Saved: vasp_files_900\CONTCAR893
# Saved: vasp_files_900\CONTCAR894
# Saved: vasp_files_900\CONTCAR895
# Saved: vasp_files_900\CONTCAR896
# Saved: vasp_files_900\CONTCAR897
# Saved: vasp_files_900\CONTCAR898
# Saved: vasp_files_900\CONTCAR899
# Saved: vasp_files_900\CONTCAR900
# Saved: vasp_files_900\CONTCAR901
# Saved: vasp_files_900\CONTCAR902
# Saved: vasp_files_900\CONTCAR903
# Saved: vasp_files_900\CONTCAR904
# Saved: vasp_files_900\CONTCAR905
# Saved: vasp_files_900\CONTCAR906
# Saved: vasp_files_900\CONTCAR907
# Saved: vasp_files_900\CONTCAR908
# Saved: vasp_files_900\CONTCAR909
# Saved: vasp_files_900\CONTCAR910
# Saved: vasp_files_900\CONTCAR911
# Saved: vasp_files_900\CONTCAR912
# Saved: vasp_files_900\CONTCAR913
# Saved: vasp_files_900\CONTCAR914
# Saved: vasp_files_900\CONTCAR915
# Saved: vasp_files_900\CONTCAR916
# Saved: vasp_files_900\CONTCAR917
# Saved: vasp_files_900\CONTCAR918
# Saved: vasp_files_900\CONTCAR919
# Saved: vasp_files_900\CONTCAR920
# Saved: vasp_files_900\CONTCAR921
# Saved: vasp_files_900\CONTCAR922
# Saved: vasp_files_900\CONTCAR923
# Saved: vasp_files_900\CONTCAR924
# Saved: vasp_files_900\CONTCAR925
# Saved: vasp_files_900\CONTCAR926
# Saved: vasp_files_900\CONTCAR927
# Saved: vasp_files_900\CONTCAR928
# Saved: vasp_files_900\CONTCAR929
# Saved: vasp_files_900\CONTCAR930
# Saved: vasp_files_900\CONTCAR931
# Saved: vasp_files_900\CONTCAR932
# Saved: vasp_files_900\CONTCAR933
# Saved: vasp_files_900\CONTCAR934
# Saved: vasp_files_900\CONTCAR935
# Saved: vasp_files_900\CONTCAR936
# Saved: vasp_files_900\CONTCAR937
# Saved: vasp_files_900\CONTCAR938
# Saved: vasp_files_900\CONTCAR939
# Saved: vasp_files_900\CONTCAR940
# Saved: vasp_files_900\CONTCAR941
# Saved: vasp_files_900\CONTCAR942
# Saved: vasp_files_900\CONTCAR943
# Saved: vasp_files_900\CONTCAR944
# Saved: vasp_files_900\CONTCAR945
# Saved: vasp_files_900\CONTCAR946
# Saved: vasp_files_900\CONTCAR947
# Saved: vasp_files_900\CONTCAR948
# Saved: vasp_files_900\CONTCAR949
# Saved: vasp_files_900\CONTCAR950
# Saved: vasp_files_900\CONTCAR951
# Saved: vasp_files_900\CONTCAR952
# Saved: vasp_files_900\CONTCAR953
# Saved: vasp_files_900\CONTCAR954
# Saved: vasp_files_900\CONTCAR955
# Saved: vasp_files_900\CONTCAR956
# Saved: vasp_files_900\CONTCAR957
# Saved: vasp_files_900\CONTCAR958
# Saved: vasp_files_900\CONTCAR959
# Saved: vasp_files_900\CONTCAR960
# Saved: vasp_files_900\CONTCAR961
# Saved: vasp_files_900\CONTCAR962
# Saved: vasp_files_900\CONTCAR963
# Saved: vasp_files_900\CONTCAR964
# Saved: vasp_files_900\CONTCAR965
# Saved: vasp_files_900\CONTCAR966
# Saved: vasp_files_900\CONTCAR967
# Saved: vasp_files_900\CONTCAR968
# Saved: vasp_files_900\CONTCAR969
# Saved: vasp_files_900\CONTCAR970
# Saved: vasp_files_900\CONTCAR971
# Saved: vasp_files_900\CONTCAR972
# Saved: vasp_files_900\CONTCAR973
# Saved: vasp_files_900\CONTCAR974
# Saved: vasp_files_900\CONTCAR975
# Saved: vasp_files_900\CONTCAR976
# Saved: vasp_files_900\CONTCAR977
# Saved: vasp_files_900\CONTCAR978
# Saved: vasp_files_900\CONTCAR979
# Saved: vasp_files_900\CONTCAR980
# Saved: vasp_files_900\CONTCAR981
# Saved: vasp_files_900\CONTCAR982
# Saved: vasp_files_900\CONTCAR983
# Saved: vasp_files_900\CONTCAR984
# Saved: vasp_files_900\CONTCAR985
# Saved: vasp_files_900\CONTCAR986
# Saved: vasp_files_900\CONTCAR987
# Saved: vasp_files_900\CONTCAR988
# Saved: vasp_files_900\CONTCAR989
# Saved: vasp_files_900\CONTCAR990
# Saved: vasp_files_900\CONTCAR991
# Saved: vasp_files_900\CONTCAR992
# Saved: vasp_files_900\CONTCAR993
# Saved: vasp_files_900\CONTCAR994
# Saved: vasp_files_900\CONTCAR995
# Saved: vasp_files_900\CONTCAR996
# Saved: vasp_files_900\CONTCAR997
# Saved: vasp_files_900\CONTCAR998
# Saved: vasp_files_900\CONTCAR999
# Saved: vasp_files_900\CONTCAR1000
# Saved: vasp_files_900\CONTCAR1001

# %%
import os
from ase.io import read
from pymatgen.core.structure import Structure

# Define the directory containing CONTCAR files
#vasp_dir = r"D:\docuents_trans_2_20_24\sai_mat\vijay_sir_project\md_inputs\von_1200_latest\vasp_files_50ps"
vasp_dir = r"E:\2_4_6\1000\vasp_files_900"


# List all CONTCAR files in the directory
contcar_files = [os.path.join(vasp_dir, f) for f in os.listdir(vasp_dir) if f.startswith("CONTCAR")]

# Sort files to ensure they are processed in order (e.g., CONTCAR1, CONTCAR2, ...)
contcar_files.sort()

# Convert all CONTCAR files to pymatgen Structures
structures = []
for contcar_file in contcar_files:
    # Read the VASP file using ASE
    atoms = read(contcar_file)
    
    # Extract data from ASE Atoms object
    species = atoms.get_chemical_symbols()  # Atomic species
    positions = atoms.get_positions()       # Atomic positions (Cartesian coordinates)
    lattice = atoms.get_cell()              # Lattice vectors (simulation box)
    
    # Convert to pymatgen Structure object
    structure = Structure(lattice, species, positions)
    structures.append(structure)

    print(f"Loaded structure from: {contcar_file}")

# Print summary
print(f"Number of structures loaded: {len(structures)}")
# Out:
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR1
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR10
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR100
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR1000
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR1001
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR101
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR102
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR103
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR104
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR105
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR106
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR107
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR108
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR109
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR11
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR110
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR111
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR112
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR113
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR114
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR115
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR116
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR117
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR118
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR119
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR12
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR120
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR121
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR122
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR123
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR124
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR125
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR126
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR127
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR128
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR129
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR13
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR130
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR131
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR132
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR133
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR134
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR135
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR136
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR137
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR138
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR139
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR14
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR140
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR141
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR142
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR143
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR144
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR145
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR146
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR147
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR148
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR149
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR15
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR150
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR151
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR152
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR153
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR154
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR155
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR156
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR157
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR158
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR159
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR16
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR160
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR161
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR162
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR163
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR164
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR165
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR166
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR167
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR168
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR169
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR17
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR170
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR171
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR172
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR173
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR174
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR175
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR176
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR177
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR178
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR179
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR18
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR180
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR181
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR182
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR183
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR184
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR185
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR186
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR187
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR188
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR189
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR19
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR190
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR191
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR192
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR193
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR194
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR195
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR196
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR197
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR198
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR199
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR2
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR20
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR200
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR201
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR202
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR203
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR204
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR205
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR206
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR207
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR208
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR209
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR21
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR210
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR211
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR212
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR213
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR214
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR215
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR216
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR217
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR218
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR219
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR22
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR220
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR221
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR222
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR223
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR224
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR225
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR226
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR227
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR228
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR229
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR23
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR230
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR231
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR232
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR233
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR234
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR235
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR236
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR237
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR238
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR239
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR24
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR240
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR241
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR242
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR243
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR244
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR245
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR246
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR247
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR248
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR249
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR25
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR250
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR251
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR252
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR253
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR254
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR255
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR256
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR257
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR258
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR259
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR26
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR260
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR261
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR262
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR263
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR264
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR265
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR266
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR267
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR268
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR269
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR27
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR270
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR271
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR272
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR273
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR274
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR275
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR276
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR277
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR278
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR279
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR28
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR280
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR281
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR282
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR283
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR284
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR285
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR286
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR287
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR288
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR289
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR29
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR290
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR291
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR292
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR293
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR294
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR295
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR296
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR297
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR298
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR299
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR3
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR30
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR300
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR301
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR302
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR303
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR304
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR305
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR306
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR307
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR308
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR309
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR31
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR310
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR311
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR312
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR313
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR314
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR315
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR316
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR317
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR318
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR319
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR32
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR320
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR321
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR322
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR323
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR324
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR325
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR326
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR327
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR328
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR329
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR33
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR330
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR331
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR332
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR333
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR334
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR335
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR336
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR337
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR338
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR339
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR34
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR340
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR341
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR342
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR343
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR344
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR345
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR346
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR347
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR348
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR349
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR35
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR350
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR351
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR352
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR353
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR354
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR355
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR356
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR357
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR358
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR359
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR36
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR360
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR361
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR362
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR363
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR364
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR365
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR366
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR367
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR368
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR369
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR37
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR370
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR371
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR372
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR373
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR374
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR375
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR376
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR377
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR378
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR379
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR38
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR380
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR381
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR382
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR383
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR384
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR385
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR386
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR387
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR388
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR389
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR39
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR390
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR391
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR392
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR393
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR394
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR395
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR396
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR397
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR398
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR399
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR4
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR40
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR400
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR401
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR402
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR403
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR404
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR405
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR406
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR407
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR408
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR409
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR41
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR410
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR411
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR412
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR413
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR414
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR415
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR416
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR417
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR418
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR419
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR42
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR420
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR421
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR422
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR423
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR424
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR425
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR426
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR427
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR428
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR429
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR43
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR430
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR431
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR432
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR433
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR434
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR435
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR436
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR437
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR438
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR439
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR44
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR440
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR441
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR442
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR443
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR444
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR445
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR446
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR447
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR448
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR449
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR45
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR450
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR451
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR452
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR453
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR454
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR455
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR456
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR457
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR458
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR459
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR46
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR460
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR461
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR462
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR463
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR464
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR465
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR466
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR467
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR468
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR469
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR47
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR470
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR471
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR472
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR473
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR474
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR475
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR476
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR477
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR478
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR479
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR48
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR480
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR481
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR482
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR483
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR484
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR485
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR486
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR487
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR488
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR489
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR49
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR490
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR491
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR492
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR493
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR494
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR495
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR496
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR497
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR498
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR499
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR5
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR50
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR500
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR501
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR502
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR503
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR504
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR505
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR506
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR507
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR508
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR509
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR51
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR510
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR511
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR512
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR513
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR514
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR515
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR516
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR517
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR518
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR519
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR52
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR520
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR521
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR522
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR523
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR524
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR525
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR526
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR527
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR528
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR529
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR53
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR530
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR531
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR532
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR533
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR534
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR535
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR536
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR537
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR538
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR539
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR54
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR540
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR541
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR542
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR543
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR544
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR545
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR546
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR547
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR548
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR549
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR55
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR550
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR551
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR552
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR553
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR554
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR555
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR556
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR557
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR558
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR559
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR56
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR560
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR561
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR562
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR563
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR564
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR565
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR566
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR567
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR568
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR569
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR57
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR570
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR571
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR572
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR573
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR574
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR575
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR576
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR577
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR578
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR579
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR58
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR580
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR581
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR582
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR583
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR584
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR585
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR586
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR587
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR588
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR589
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR59
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR590
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR591
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR592
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR593
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR594
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR595
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR596
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR597
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR598
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR599
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR6
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR60
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR600
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR601
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR602
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR603
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR604
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR605
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR606
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR607
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR608
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR609
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR61
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR610
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR611
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR612
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR613
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR614
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR615
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR616
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR617
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR618
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR619
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR62
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR620
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR621
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR622
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR623
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR624
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR625
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR626
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR627
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR628
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR629
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR63
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR630
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR631
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR632
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR633
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR634
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR635
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR636
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR637
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR638
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR639
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR64
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR640
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR641
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR642
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR643
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR644
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR645
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR646
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR647
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR648
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR649
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR65
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR650
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR651
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR652
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR653
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR654
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR655
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR656
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR657
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR658
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR659
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR66
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR660
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR661
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR662
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR663
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR664
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR665
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR666
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR667
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR668
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR669
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR67
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR670
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR671
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR672
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR673
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR674
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR675
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR676
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR677
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR678
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR679
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR68
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR680
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR681
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR682
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR683
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR684
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR685
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR686
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR687
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR688
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR689
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR69
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR690
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR691
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR692
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR693
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR694
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR695
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR696
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR697
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR698
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR699
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR7
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR70
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR700
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR701
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR702
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR703
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR704
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR705
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR706
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR707
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR708
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR709
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR71
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR710
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR711
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR712
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR713
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR714
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR715
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR716
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR717
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR718
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR719
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR72
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR720
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR721
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR722
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR723
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR724
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR725
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR726
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR727
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR728
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR729
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR73
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR730
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR731
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR732
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR733
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR734
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR735
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR736
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR737
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR738
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR739
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR74
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR740
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR741
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR742
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR743
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR744
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR745
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR746
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR747
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR748
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR749
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR75
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR750
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR751
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR752
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR753
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR754
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR755
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR756
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR757
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR758
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR759
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR76
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR760
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR761
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR762
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR763
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR764
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR765
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR766
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR767
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR768
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR769
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR77
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR770
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR771
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR772
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR773
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR774
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR775
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR776
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR777
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR778
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR779
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR78
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR780
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR781
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR782
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR783
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR784
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR785
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR786
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR787
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR788
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR789
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR79
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR790
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR791
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR792
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR793
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR794
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR795
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR796
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR797
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR798
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR799
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR8
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR80
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR800
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR801
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR802
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR803
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR804
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR805
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR806
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR807
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR808
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR809
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR81
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR810
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR811
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR812
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR813
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR814
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR815
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR816
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR817
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR818
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR819
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR82
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR820
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR821
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR822
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR823
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR824
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR825
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR826
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR827
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR828
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR829
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR83
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR830
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR831
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR832
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR833
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR834
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR835
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR836
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR837
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR838
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR839
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR84
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR840
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR841
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR842
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR843
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR844
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR845
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR846
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR847
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR848
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR849
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR85
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR850
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR851
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR852
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR853
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR854
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR855
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR856
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR857
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR858
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR859
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR86
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR860
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR861
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR862
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR863
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR864
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR865
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR866
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR867
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR868
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR869
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR87
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR870
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR871
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR872
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR873
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR874
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR875
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR876
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR877
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR878
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR879
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR88
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR880
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR881
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR882
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR883
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR884
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR885
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR886
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR887
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR888
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR889
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR89
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR890
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR891
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR892
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR893
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR894
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR895
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR896
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR897
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR898
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR899
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR9
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR90
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR900
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR901
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR902
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR903
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR904
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR905
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR906
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR907
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR908
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR909
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR91
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR910
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR911
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR912
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR913
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR914
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR915
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR916
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR917
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR918
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR919
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR92
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR920
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR921
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR922
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR923
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR924
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR925
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR926
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR927
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR928
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR929
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR93
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR930
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR931
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR932
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR933
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR934
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR935
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR936
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR937
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR938
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR939
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR94
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR940
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR941
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR942
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR943
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR944
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR945
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR946
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR947
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR948
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR949
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR95
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR950
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR951
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR952
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR953
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR954
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR955
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR956
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR957
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR958
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR959
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR96
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR960
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR961
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR962
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR963
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR964
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR965
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR966
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR967
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR968
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR969
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR97
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR970
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR971
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR972
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR973
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR974
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR975
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR976
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR977
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR978
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR979
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR98
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR980
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR981
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR982
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR983
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR984
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR985
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR986
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR987
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR988
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR989
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR99
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR990
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR991
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR992
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR993
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR994
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR995
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR996
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR997
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR998
# Loaded structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR999
# Number of structures loaded: 1001

# %%
import os
from ase.io import read
from pymatgen.core.structure import Structure

# Define the directory containing CONTCAR files
#vasp_dir = r"D:\docuents_trans_2_20_24\sai_mat\vijay_sir_project\md_inputs\von_1200_latest\vasp_files"

# Define the output directory for filtered structures
#output_dir = r"D:\docuents_trans_2_20_24\sai_mat\vijay_sir_project\md_inputs\von_1200_latest\filtered_vasp_files_50ps"
output_dir = r"E:\2_4_6\1000\fileterd_vasp_files_1000K"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# List all CONTCAR files in the directory
contcar_files = [os.path.join(vasp_dir, f) for f in os.listdir(vasp_dir) if f.startswith("CONTCAR")]

# Sort files to ensure they are processed in order (e.g., CONTCAR1, CONTCAR2, ...)
contcar_files.sort()

# Convert every 10th CONTCAR file to pymatgen Structures and save to a new folder
structures = []
for i, contcar_file in enumerate(contcar_files):
    if i % 10== 0:  # Process every 10th structure
        # Read the VASP file using ASE
        atoms = read(contcar_file)
        
        # Extract data from ASE Atoms object
        species = atoms.get_chemical_symbols()  # Atomic species
        positions = atoms.get_positions()       # Atomic positions (Cartesian coordinates)
        lattice = atoms.get_cell()              # Lattice vectors (simulation box)
        
        # Convert to pymatgen Structure object
        structure = Structure(lattice, species, positions)
        structures.append(structure)

        # Save the structure as a new CONTCAR file in the output directory
        output_file = os.path.join(output_dir, f"CONTCAR_{i+1}")
        structure.to(filename=output_file, fmt="poscar")  # Save as POSCAR/CONTCAR format
        
        print(f"Processed and saved structure from: {contcar_file} to {output_file}")

# Print summary of filtered structures
print(f"Number of structures saved: {len(structures)}")
# Out:
# C:\Users\DEBS\AppData\Roaming\Python\Python311\site-packages\pymatgen\io\vasp\inputs.py:660: EncodingWarning: We strongly encourage explicit `encoding`, and we would use UTF-8 by default as per PEP 686
#   with zopen(filename, mode="wt") as file:
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR1 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_1
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR106 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_11
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR115 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_21
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR124 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_31
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR133 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_41
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR142 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_51
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR151 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_61
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR160 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_71
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR17 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_81
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR179 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_91
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR188 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_101
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR197 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_111
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR205 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_121
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR214 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_131
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR223 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_141
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR232 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_151
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR241 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_161
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR250 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_171
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR26 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_181
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR269 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_191
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR278 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_201
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR287 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_211
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR296 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_221
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR304 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_231
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR313 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_241
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR322 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_251
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR331 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_261
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR340 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_271
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR35 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_281
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR359 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_291
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR368 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_301
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR377 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_311
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR386 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_321
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR395 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_331
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR403 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_341
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR412 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_351
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR421 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_361
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR430 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_371
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR44 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_381
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR449 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_391
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR458 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_401
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR467 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_411
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR476 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_421
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR485 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_431
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR494 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_441
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR502 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_451
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR511 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_461
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR520 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_471
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR53 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_481
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR539 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_491
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR548 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_501
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR557 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_511
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR566 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_521
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR575 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_531
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR584 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_541
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR593 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_551
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR601 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_561
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR610 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_571
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR62 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_581
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR629 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_591
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR638 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_601
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR647 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_611
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR656 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_621
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR665 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_631
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR674 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_641
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR683 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_651
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR692 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_661
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR700 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_671
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR71 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_681
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR719 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_691
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR728 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_701
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR737 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_711
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR746 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_721
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR755 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_731
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR764 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_741
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR773 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_751
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR782 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_761
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR791 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_771
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR80 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_781
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR809 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_791
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR818 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_801
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR827 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_811
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR836 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_821
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR845 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_831
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR854 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_841
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR863 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_851
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR872 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_861
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR881 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_871
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR890 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_881
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR9 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_891
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR908 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_901
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR917 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_911
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR926 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_921
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR935 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_931
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR944 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_941
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR953 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_951
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR962 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_961
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR971 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_971
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR980 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_981
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR99 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_991
# Processed and saved structure from: E:\2_4_6\1000\vasp_files_900\CONTCAR999 to E:\2_4_6\1000\fileterd_vasp_files_1000K\CONTCAR_1001
# Number of structures saved: 101

# %%
from pymatgen.analysis.diffusion.analyzer import DiffusionAnalyzer

# Perform diffusion analysis on the loaded structures
diff_analyzer = DiffusionAnalyzer.from_structures(
    structures=structures,  # Your list of pymatgen Structure objects
    specie="Mg",            # The species for which you want to analyze diffusion
    temperature=300,        # Temperature in Kelvin
    time_step=2,            # Time step between frames in femtoseconds
    step_skip=100000,         # Skip every 1000 steps for smoother analysis
    smoothed="constant",    # Smoothing method (can also be "max")
    avg_nsteps=80  # Number of steps for averaging (smaller window for finer resolution)
)

# # Print diffusivity and other properties
# print(f"Diffusivity: {diff_analyzer.diffusivity} cm^2/s")
# print(f"Mean squared displacement (MSD):\n{diff_analyzer.msd}")
# print(f"Vacancy corrected diffusivity: {diff_analyzer.vacancy_corrected_diffusivity} cm^2/s")

# %%
# Plot the smoothed MSD vs. time graph
diff_analyzer.plot_msd(mode="site")  # Default mode plots MSD for all directions combined
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Plot the smoothed MSD vs. time graph
# ----> 2 diff_analyzer.plot_msd(mode="site")  # Default mode plots MSD for all directions combined
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pymatgen\analysis\diffusion\analyzer.py:567, in DiffusionAnalyzer.plot_msd(self, mode)
#     556 def plot_msd(self, mode="default"):
#     557     """
#     558     Plot the smoothed msd vs time graph. Useful for checking convergence.
#     559
#    (...)
#     565             displacement for diffusing specie).
#     566     """
# --> 567     self.get_msd_plot(mode=mode).show()
#
# AttributeError: 'Axes' object has no attribute 'show'

# %%
diff_analyzer.get_summary_dict(include_msd_t=False, include_mscd_t=False)
# Out:
# {'D': 5.665471467098321e-06,
#  'D_sigma': 5.388192948674165e-08,
#  'D_charge': 6.4783789183252755e-06,
#  'D_charge_sigma': 5.7729180187058006e-08,
#  'S': 191.4416737215525,
#  'S_sigma': 1.8207216864815743,
#  'S_charge': 218.9105902887584,
#  'D_components': [3.210142441043861e-06,
#   6.622655050204811e-06,
#   7.163616910046286e-06],
#  'S_components': [108.47376875287362, 223.785818118515, 242.06543429326868],
#  'D_components_sigma': [2.8871945806032517e-08,
#   8.265171076039295e-08,
#   7.125955942219103e-08],
#  'S_components_sigma': [0.9756105314101479,
#   2.792879981094198,
#   2.4079283434167063],
#  'specie': 'Mg',
#  'step_skip': 100000,
#  'time_step': 2,
#  'temperature': 300,
#  'max_framework_displacement': 156.71850657472504,
#  'Haven_ratio': 0.8745199282913975}

# %%
# Plot MSCD
ax = diff_analyzer.get_msd_plot(mode="mscd")
ax.set_title("Mean Squared Charge Displacement (MSCD)")
ax.figure.show()
# Out:
# C:\Users\DEBS\AppData\Local\Temp\ipykernel_960\2420837355.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   ax.figure.show()

# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Extract MSD and time data
msd = diff_analyzer.msd  # Mean squared displacement (in Å²)
delta_t = diff_analyzer.dt  # Time intervals (in ps)

# Perform linear regression to find slope
slope, intercept, r_value, p_value, std_err = linregress(delta_t, msd)

# Calculate diffusivity in Å²/ps using the Einstein relation
diffusivity_A2_per_ps = slope / 6  # Diffusivity in Å²/fs

# Convert diffusivity from Å²/ps to cm²/s
# 1 Å² = 1e-16 cm², 1 ps = 1e-12 s, so conversion factor is 1e-4
diffusivity_cm2_per_s = diffusivity_A2_per_ps * 1e-1  # Convert to cm²/s

# Plot MSD and linear fit
plt.plot(delta_t, msd, label="MSD", color="blue")
plt.plot(delta_t, slope * delta_t + intercept, label=f"Linear fit: y = {slope:.6f}x + {intercept:.6f}", color="red", linestyle="--")
plt.xlabel("Time (fs)")
plt.ylabel("MSD (Å²)")
plt.title("Mean Squared Displacement vs Time")
plt.legend()
plt.show()

# Report the results
print(f"Slope: {slope:.6e} (Å²/ps)")
print(f"Diffusivity in Å²/ps: {diffusivity_A2_per_ps:.6e}")
print(f"Diffusivity in cm²/s: {diffusivity_cm2_per_s:.6e}")
print(f"R-squared value: {r_value**2:.6f}")
# Out:
# Slope: 3.399283e-04 (Å²/ps)
# Diffusivity in Å²/ps: 5.665471e-05
# Diffusivity in cm²/s: 5.665471e-06
# R-squared value: 0.998284

# %%
#diff_calc.plot_msd(mode='default')
diff_analyzer.export_msdt("md_50ps")
import os
import pandas as pd
msd_md = pd.read_table("md_50ps", delimiter=' ')
print(msd_md)
# Out:
#           #            t         MSD       MSD_a       MSD_b        MSD_c  \
# 0         0     0.000000    0.000000    0.000000    0.000000     0.000000
# 1    200000    78.567527   19.227579   27.199943   32.140005    93.608516
# 2    400000   133.951126   32.475682   47.996184   53.479260   160.401783
# 3    600000   186.646945   44.234098   68.372082   74.040765   224.041572
# 4    800000   242.668653   56.240130   89.227718   97.200805   290.722872
# 5   1000000   300.376848   69.574625  110.543417  120.258806   365.615335
# 6   1200000   362.997635   81.423878  134.691092  146.882665   448.821908
# 7   1400000   428.291594   94.030408  158.384873  175.876313   508.849203
# 8   1600000   500.886291  107.702747  185.082284  208.101260   586.381942
# 9   1800000   567.584013  117.498307  211.816428  238.269277   663.273025
# 10  2000000   637.649519  129.116996  240.924616  267.607907   759.525182
# 11  2200000   712.438397  141.231208  271.015679  300.191510   866.444249
# 12  2400000   782.363601  154.056304  300.862858  327.444439   946.058512
# 13  2600000   851.750180  166.215925  326.702233  358.832023  1026.482533
# 14  2800000   923.128897  179.520244  354.084405  389.524249  1114.764749
# 15  3000000   992.279408  193.930585  380.214258  418.134564  1176.751293
# 16  3200000  1065.260538  207.300478  408.787659  449.172401  1238.209752
# 17  3400000  1136.684658  221.767388  437.496740  477.420531  1305.400697
# 18  3600000  1208.870753  235.353790  466.685438  506.831525  1378.585455
# 19  3800000  1285.214063  250.931153  496.886323  537.396588  1458.624152
# 20  4000000  1362.574260  268.262474  529.821392  564.490394  1538.030045
#
#     MSCD
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming msd_md is already loaded as a DataFrame
time_fs = msd_md['#']
time = time_fs / 1000  # Convert time to ps

# MSD series
msd_a = msd_md['MSD']
msd_b = msd_md['MSD_a']
msd_c = msd_md['MSD_b']
msd_t = msd_md['t']

# Define delta_t values (in ps)
delta_t_steps = np.arange(0, 4200, 200)  # Delta t: 200, 400, ..., 4000

# Initialize lists for storing results
delta_t_values = [0]  # Start with the origin point (0, 0)
MSD_a_averages = [0]  # Start with MSD = 0 at delta_t = 0
MSD_b_averages = [0]
MSD_c_averages = [0]
MSD_t_averages = [0]

# Calculate MSD for each delta_t
for delta_t in delta_t_steps:
    msd_a_values = []  # To store MSD for each interval in msd_a
    msd_b_values = []  # To store MSD for each interval in msd_b
    msd_c_values = []  # To store MSD for each interval in msd_c
    msd_t_values = []  # To store MSD for each interval in msd_t

    # Loop through valid time windows based on delta_t
    for start_idx in range(len(msd_a) - delta_t // 200):  # 200 ps corresponds to a step size of 1 in your data
        end_idx = start_idx + delta_t // 200  # Calculate the index for delta_t

        # Ensure the indices are valid
        if end_idx < len(msd_a):
            # Calculate MSD for each series
            msd_a_values.append(msd_a.iloc[end_idx] - msd_a.iloc[start_idx])
            msd_b_values.append(msd_b.iloc[end_idx] - msd_b.iloc[start_idx])
            msd_c_values.append(msd_c.iloc[end_idx] - msd_c.iloc[start_idx])
            msd_t_values.append(msd_t.iloc[end_idx] - msd_t.iloc[start_idx])

    # Calculate the average MSD for this delta_t if valid values are found
    if msd_a_values:
        MSD_a_averages.append(np.mean(msd_a_values))
        MSD_b_averages.append(np.mean(msd_b_values))
        MSD_c_averages.append(np.mean(msd_c_values))
        MSD_t_averages.append(np.mean(msd_t_values))
        delta_t_values.append(delta_t)

# Plot MSD vs Delta t
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the MSD data with continuous lines (no markers)
ax.plot(delta_t_values, MSD_a_averages, '-', label='MSD a', linewidth=2, color='b')
ax.plot(delta_t_values, MSD_b_averages, '-', label='MSD b', linewidth=2, color='g')
ax.plot(delta_t_values, MSD_c_averages, '-', label='MSD c', linewidth=2, color='m')
ax.plot(delta_t_values, MSD_t_averages, '-', label='Overall MSD', linewidth=2, color='r')

# Add a linear regression line for the overall MSD
slope, intercept, r_value, p_value, std_err = linregress(delta_t_values, MSD_t_averages)
r_squared = r_value**2
ax.plot(delta_t_values, intercept + slope * np.array(delta_t_values), '--', label=f'Linear Fit', color='black', linewidth=2)

# Axis labels and legend
ax.set_xlabel(r'$\Delta t$ (ps)', fontsize=16, fontweight='bold', labelpad=8)
ax.set_ylabel('MSD ($\mathrm{\AA^2}$)', fontsize=16, fontweight='bold', labelpad=8)
ax.legend(loc="upper left", fontsize=14)

# Adjust axis line widths
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.8)

# Set ticks and styles
plt.xticks(weight='bold', fontsize=14)
plt.yticks(weight='bold', fontsize=14)
plt.tick_params(direction='in')
plt.xlim(0, 4000)
# Show the plot
plt.tight_layout()

# Save the figure as PDF
plt.savefig("msd_vs_delta_t_all_series_300_continuous.pdf", format='pdf')
plt.savefig("msd_vs_delta_t_all_series_300_continuous.tif", format='tif')

# Display the plot
plt.show()

# Print the calculated diffusivity
print(f"Diffusion Coefficient (Å^2/ps): {slope / 6:.6f}")
print(f"Diffusion Coefficient (cm^2/s): {slope / 6 * 1e-4:.6e}")
# Out:
# Diffusion Coefficient (Å^2/ps): 0.056512
# Diffusion Coefficient (cm^2/s): 5.651171e-06

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming msd_md is your DataFrame
time_ps = msd_md['#'] / 1000  # Convert time to picoseconds
MSCD = msd_md['MSD_c']  # MSCD values

# Define delta_t values (in ps)
delta_t_steps = np.arange(0, 4200, 200)  # Delta t: 200, 400, ..., 4000

# Initialize lists for storing results
delta_t_values = [0]  # Start with delta_t = 0
MSD_averages = [0]  # Start with MSD = 0 at delta_t = 0

# Loop over each delta_t value (200, 400, 600, ..., 4000)
for delta_t in delta_t_steps:
    msd_values = []  # To store MSD for each interval at delta_t
    
    # Loop over the valid time windows for each delta_t
    for start_idx in range(0, len(MSCD) - delta_t // 200):
        end_idx = start_idx + delta_t // 200
        
        if end_idx < len(MSCD):  # Ensure valid indices
            msd = MSCD.iloc[end_idx] - MSCD.iloc[start_idx]  # Calculate MSCD for this interval
            msd_values.append(msd)
    
    # Calculate the average MSD for this delta_t if valid values exist
    if msd_values:
        avg_msd = np.mean(msd_values)
        delta_t_values.append(delta_t)
        MSD_averages.append(avg_msd)

# Linear regression and R² calculation
slope, intercept, r_value, p_value, std_err = linregress(delta_t_values, MSD_averages)
r_squared = r_value**2

# Now, plotting the results
plt.figure(figsize=(10, 6))
plt.plot(delta_t_values, MSD_averages, 'o-', label='MSD vs Delta t', color='blue')

# Plot the linear fit
plt.plot(delta_t_values, intercept + slope * np.array(delta_t_values), '--', label=f'Linear Fit (R² = {r_squared:.4f})', color='red')

# Labeling the plot
plt.xlabel('Delta t (ps)', fontsize=14)
plt.ylabel('MSD ($\mathrm{\AA^2}$)', fontsize=14)
plt.title('MSD vs Delta t', fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)
#plt.xlim(0, 4000)

# Show the plot
plt.show()

# Print the regression results
print(f"Slope: {slope:.6f}")
print(f"Intercept: {intercept:.6f}")
print(f"R² Score: {r_squared:.6f}")

# Print the average MSD values for each delta_t
for delta_t, avg_msd in zip(delta_t_values, MSD_averages):
    print(f"Delta t = {delta_t} ps, Average MSD = {avg_msd:.6f}")
# Out:
# Slope: 0.384521
# Intercept: 5.110624
# R² Score: 0.999552
# Delta t = 0 ps, Average MSD = 0.000000
# Delta t = 0 ps, Average MSD = 0.000000
# Delta t = 200 ps, Average MSD = 76.901502
# Delta t = 400 ps, Average MSD = 152.791878
# Delta t = 600 ps, Average MSD = 228.957186
# Delta t = 800 ps, Average MSD = 306.034616
# Delta t = 1000 ps, Average MSD = 384.379710
# Delta t = 1200 ps, Average MSD = 464.080754
# Delta t = 1400 ps, Average MSD = 544.796725
# Delta t = 1600 ps, Average MSD = 626.522114
# Delta t = 1800 ps, Average MSD = 708.705338
# Delta t = 2000 ps, Average MSD = 791.603207
# Delta t = 2200 ps, Average MSD = 870.763528
# Delta t = 2400 ps, Average MSD = 944.940451
# Delta t = 2600 ps, Average MSD = 1018.098436
# Delta t = 2800 ps, Average MSD = 1089.593451
# Delta t = 3000 ps, Average MSD = 1160.201886
# Delta t = 3200 ps, Average MSD = 1230.015072
# Delta t = 3400 ps, Average MSD = 1300.647119
# Delta t = 3600 ps, Average MSD = 1373.743117
# Delta t = 3800 ps, Average MSD = 1451.522840
# Delta t = 4000 ps, Average MSD = 1538.030045

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Assuming msd_md is your DataFrame
time_ps = msd_md['#'] / 1000  # Convert time to picoseconds
MSCD = msd_md['MSD_c']  # MSCD values

# Define delta_t values (in ps)
delta_t_steps = np.arange(0, 4200, 200)  # Delta t: 200, 400, ..., 4000

# Initialize lists for storing results
delta_t_values = [0]  # Start with delta_t = 0
MSD_averages = [0]  # Start with MSD = 0 at delta_t = 0

# Loop over each delta_t value (200, 400, 600, ..., 4000)
for delta_t in delta_t_steps:
    msd_values = []  # To store MSD for each interval at delta_t
    
    # Loop over the valid time windows for each delta_t
    for start_idx in range(0, len(MSCD) - delta_t // 200):
        end_idx = start_idx + delta_t // 200
        
        if end_idx < len(MSCD):  # Ensure valid indices
            msd = MSCD.iloc[end_idx] - MSCD.iloc[start_idx]  # Calculate MSCD for this interval
            msd_values.append(msd)
    
    # Calculate the average MSD for this delta_t if valid values exist
    if msd_values:
        avg_msd = np.mean(msd_values)
        delta_t_values.append(delta_t)
        MSD_averages.append(avg_msd)

# Perform linear regression to find the slope (m) and intercept
slope, intercept, r_value, p_value, std_err = linregress(delta_t_values[1:], MSD_averages[1:])

# R² score (coefficient of determination)
r_squared = r_value**2

# Now, plotting the results
plt.figure(figsize=(10, 6))
plt.plot(delta_t_values, MSD_averages, 'o-', label='MSD vs Delta t_300', color='blue')

# Plot the linear fit (y = mx)
plt.plot(delta_t_values, intercept + slope * np.array(delta_t_values), '--', label=f'Linear Fit: y = {slope:.4f}x (R² = {r_squared:.4f})', color='red')

# Labeling the plot
plt.xlabel('Delta t (ps)', fontsize=14)
plt.ylabel('MSD ($\mathrm{\AA^2}$)', fontsize=14)
plt.title('MSD vs Delta t (Linear Fit)', fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)

# Show the plot
plt.show()

# Print the slope (m), intercept, and R² score
print(f"Slope (m): {slope:.6f}")
print(f"Intercept: {intercept:.6f}")
print(f"R² Score: {r_squared:.6f}")

# Save the MSCD and delta_t values in an Excel file
result_df = pd.DataFrame({
    'Time (ps)': delta_t_values[1:],  # Skip the first entry (0 ps)
    'MSD (Å²)': MSD_averages[1:]  # Skip the first entry (MSD = 0)
})

# Save the DataFrame to an Excel file
result_df.to_excel('msd_vs_delta_t_1000.xlsx', index=False)

print("Results have been saved to 'msd_vs_delta_t.xlsx'.")
# Out:
# Slope (m): 0.384189
# Intercept: 6.017705
# R² Score: 0.999503
# Results have been saved to 'msd_vs_delta_t.xlsx'.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Load the data from the Excel file
df_mscd = pd.read_excel("msd_vs_delta_t_900.xlsx")

# Extract the data using the correct column names
time_ps = df_mscd['Time (ps)']
MSD_values = df_mscd['MSD (Å²)']

# Perform linear regression to calculate the slope
slope, intercept, r_value, p_value, std_err = linregress(time_ps, MSD_values)

# Perform the requested operations
result = (slope / 6) * 1e-4

# Print the slope and the final result
print(f"Slope: {slope:.6f} Å²/ps")
print(f"Final Result: {result:.6e} cm²/s")

# Plot the curve
plt.figure(figsize=(10, 6))
plt.plot(time_ps, MSD_values, '-', color=(0, 0, 0.5), linewidth=3)  # Deep navy blue, thicker line
plt.plot(time_ps, intercept + slope * time_ps, '--', color='red', label=f'Linear Fit: Slope = {slope:.4f}')  # Linear fit line
plt.xlabel(r'$\Delta t$ (ps)', fontsize=16, fontweight='bold', labelpad=8)
plt.ylabel('MSCD ($\mathrm{\AA^2}$)', fontsize=16, fontweight='bold', labelpad=8)

# Adjust axis line widths
for axis in ['top', 'bottom', 'left', 'right']:
    plt.gca().spines[axis].set_linewidth(1.8)

# Set ticks and styles
plt.xticks(weight='bold', fontsize=14)
plt.yticks(weight='bold', fontsize=14)
plt.tick_params(direction='in')

# Set x-axis and y-axis limits
#plt.xlim(0, 4000)
#plt.ylim(0, 800)

# Save the plot as PDF
plt.tight_layout()
#plt.legend(fontsize=12)
plt.savefig("dd_mscd_30ps_with_fit.pdf", format='pdf')

# Display the plot
plt.show()
# Out:
# Slope: 0.384189 Å²/ps
# Final Result: 6.403158e-06 cm²/s

# %%
 5.651171e-06/6.403158e-06
