# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PyLRO import pylro
def structure_factor(pos, hkl):
    """ N*1 array"""
    F = 0
    h, k, l = hkl
    for xyz in pos:
        x,y,z = xyz
        F += np.exp(-2*np.pi*(1j)*(h*x + k*y+ l*z))

    return F
#Load a structure and fit the sublattice
###################################
#Put file info here#
file='../../S812/POSCAR.201' 
n=13
###################################


amor=pylro(file,n)
amor.lattice_fit()

pmax=13
stest=range(1,13)
a=[]
b=[]
c=[]
basis=np.array([[1,0,0,],
       [0,1,0],
       [0,0,1]])
abc=[]
for b in basis:
    s=[]
    for i in stest:
        factor=np.abs(structure_factor(amor.atom_locations,b*i))
        s.append(factor)
    abc.append(s)
    
fig=plt.figure()
plt.plot(stest,abc[0],label='a',color='b',alpha=.3)
plt.plot(stest,abc[1],label='b',color='r',alpha=.3)
plt.plot(stest,abc[2],label='c',color='g',alpha=.3)
plt.scatter(stest,abc[0],color='b')
plt.scatter(stest,abc[1],color='r')
plt.scatter(stest,abc[2],color='g')
plt.legend()
plt.ylabel('structure factor')
plt.xlabel('periodicity')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PyLRO import pylro
#Load a structure and fit the sublattice

###################################
#Put file info here#
file='../../S812/POSCAR.201' 
n=13
###################################


amor=pylro(file,n)
amor.lattice_fit()



#Create 3 subfigures to display each dimension
#Use pylro.x : pylro.y : pylro.z to get the xyz atomic locations of the atoms
fig=plt.figure(figsize=(25,3))

ax1=fig.add_subplot(131)
ax1=sns.violinplot(x=amor.x,bw_method=.08,inner=None)
ax1.scatter(amor.x,np.zeros(len(amor.x)),alpha=.7,color='r',s=100)
ax1.axis('off')



ax2=fig.add_subplot(132)
ax2=sns.violinplot(x=amor.y,bw_method=.08,inner=None)
ax2.scatter(amor.y,np.zeros(len(amor.y)),alpha=.7,color='r',s=100)
ax2.axis('off')


ax3=fig.add_subplot(133)
ax3=sns.violinplot(x=amor.z,bw_method=.08,inner=None)
ax3.scatter(amor.z,np.zeros(len(amor.z)),alpha=.7,color='r',s=100)
ax3.axis('off')

plt.show()

print('a: ',amor.plane_order([1,0,0]))
print('b: ',amor.plane_order([0,1,0]))
print('c: ',amor.plane_order([0,0,1]))
# Out:
# a:  0.15833546050000008
# b:  0.1091502987222222
# c:  0.024076789791666626

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PyLRO import pylro
#Load a structure and fit the sublattice

###################################
#Put file info here#
file='../../S812/POSCAR.201' 
n=13
###################################


amor=pylro(file,n)
amor.lattice_fit()
print('Cell Dimensions: ',amor.dimensions)

a,b,c=amor.atom_locations.T

la,lb,lc=amor.lattice_repr.T

print('a           :     sorted_a')
for i in range(len(a)):
    idx=np.argsort(a)
    print(la[i],np.round(a[i],3),'    :    ',la[idx[i]],np.round(a[idx[i]],3))
    
print('\nb           :     sorted_b')
for i in range(len(b)):
    idx=np.argsort(b)
    print(lb[i],np.round(b[i],3),'    :    ',lb[idx[i]],np.round(b[idx[i]],3))
    
print('\nc           :     sorted_c')
for i in range(len(c)):
    idx=np.argsort(c)
    print(lc[i],np.round(c[i],3),'    :    ',lc[idx[i]],np.round(c[idx[i]],3))
# Out:
# Cell Dimensions:  [4, 4, 3]
# a           :     sorted_a
# 2 0.187     :     1 0.016
# 2 0.215     :     1 0.068
# 4 0.685     :     2 0.187
# 4 0.716     :     2 0.215
# 1 0.016     :     2 0.234
# 1 0.068     :     2 0.276
# 2 0.234     :     3 0.497
# 2 0.276     :     3 0.593
# 3 0.497     :     4 0.685
# 3 0.593     :     4 0.716
# 4 0.727     :     4 0.727
# 4 0.783     :     4 0.783
#
# b           :     sorted_b
# 4 0.782     :     1 0.006
# 2 0.285     :     1 0.041
# 4 0.713     :     2 0.206
# 2 0.206     :     2 0.232
# 4 0.739     :     2 0.259
# 2 0.259     :     2 0.285
# 3 0.548     :     3 0.53
# 1 0.041     :     3 0.548
# 4 0.723     :     4 0.713
# 2 0.232     :     4 0.723
# 3 0.53     :     4 0.739
# 1 0.006     :     4 0.782
#
# c           :     sorted_c
# 1 0.246     :     1 0.245
# 1 0.258     :     1 0.246
# 1 0.245     :     1 0.246
# 1 0.246     :     1 0.258
# 3 0.909     :     2 0.572
# 3 0.914     :     2 0.572
# 2 0.572     :     2 0.591
# ...

# %%
# %matplotlib qt
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PyLRO import pylro


#Load a structure and fit the sublattice

###################################
#Put file info here#
file='../../S812/POSCAR.201' 

n=13
###################################


amor=pylro(file,n)
amor.lattice_fit()

ax = plt.figure(figsize=(20,10)).add_subplot(projection='3d')
ax.scatter(amor.x,amor.y,amor.z,color='r',s=200)
ax.scatter(amor.x_,amor.y_,amor.z_,color='k',s=25)
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('c')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from PyLRO import pylro


#Load a structure and fit the sublattice

###################################
#Put file info here#
file='../../S812/POSCAR.201' 
n=13
###################################


amor=pylro(file,n)
amor.lattice_fit()

print('Find the lattice parameter along a')
cell=np.array(amor.cell)
a=cell[0]
print('a:',a)

print('\nThe a component of each atom\'s sublattice position')
print(amor.x_)

print('\nNow in angstroms')
angs=[np.linalg.norm(x*a) for x in amor.x_]
angs=[np.round(x,3) for x in angs]
print(angs)

print('\nThe first non-zero number represents the angstrom distance along a between two nearest lattices points.')
print('This is the Lattice parameter.')
angs=np.array(angs)
print(np.min(angs[angs>0.]))
# Out:
# Find the lattice parameter along a
# a: [9.074398 0.       0.      ]
#
# The a component of each atom's sublattice position
# [0.255807   0.255807   0.76742099 0.76742099 0.         0.
#  0.255807   0.255807   0.51161399 0.51161399 0.76742099 0.76742099]
#
# Now in angstroms
# [2.321, 2.321, 6.964, 6.964, 0.0, 0.0, 2.321, 2.321, 4.643, 4.643, 6.964, 6.964]
#
# The first non-zero number represents the angstrom distance along a between two nearest lattices points.
# This is the Lattice parameter.
# 2.321

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib.cm import ScalarMappable
from matplotlib import colors
import mpl_toolkits.mplot3d.art3d as art3d


fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111,projection='3d')
mag_averages=[0.0009951303789924705, 
              0.02639890234733354, 
              0.10781558949123277, 
              0.16677641252374975, 
              0.18571129692171554, 
              0.22594924114094875, 
              0.2456556706903406, 
              0.26657182033698895, 
              0.2650905906345297, 
              0.27758018920067173, 
              0.29434357342193157, 
              0.31877721041698076, 
              0.34990387691060654]


vec_averages=[[0.7084995, 0.6034265, 0.3659302],
[0.79000467, 0.48254127, 0.37821494],
[0.88185432, 0.37039551, 0.2917878 ],
[0.82297941, 0.43148221, 0.36949694],
[0.79629113, 0.47704821, 0.37194816],
[0.7808054,  0.53399517, 0.32433329],
[0.75151348, 0.57629013, 0.32111864],
[0.69181901, 0.63076954, 0.35144878],
[0.68914754, 0.64239224, 0.33527284],
[0.66426909, 0.6644563,  0.3424097 ],
[0.63469208, 0.68317417, 0.36116341],
[0.63340469, 0.65873829, 0.40603247],
[0.61646923, 0.6232027,  0.48123185]]


vec_averages__=np.array(vec_averages)
vecmin_averages__=np.array(vec_averages)

for i in range(len(vec_averages__)):
    vec_averages__[i]*=mag_averages[i]
    vecmin_averages__[i]*=mag_averages[i]*.25
    
major_axis = np.array([(vec_averages__[i][2]**2 + ((vec_averages__[i][0]+vec_averages__[i][1])/2)**2)**.5 
                       for i in range(len(vec_averages__))])  
minor_axis = np.array([(vecmin_averages__[i][2]**2 + ((vecmin_averages__[i][0]+vecmin_averages__[i][1])/2)**2)**.5 
                       for i in range(len(vecmin_averages__))])  # Lengths for the major axis

rotation_angles = np.array([math.degrees(math.atan(((vec_averages__[i][1]+vec_averages__[i][0])/2)/vec_averages__[i][2])) for i in range(len(vec_averages__))])  


num_ovals = len(major_axis)
colors = plt.cm.viridis(np.linspace(0, 1, num_ovals))  
alph=np.linspace(1,.2,13)

for i in list(range(num_ovals)):
    width = major_axis[i]  
    height = minor_axis[i]  # *2 is to
    angle = rotation_angles[i]  
    
    # Create an ellipse and add it to the plot
    center=(major_axis[i]/2*np.cos(np.deg2rad(rotation_angles[i])),
            major_axis[i]/2*np.sin(np.deg2rad(rotation_angles[i])))
    # center=(0,0)
    ellipse = Ellipse(xy=center, width=width, height=height,
                      angle=angle, edgecolor='black', facecolor=colors[i],alpha=alph[i])
    
    ax.add_patch(ellipse)
    art3d.pathpatch_2d_to_3d(ellipse, z=i/13,zdir='z')





n=.25

origin = np.array([0, 0, 1])
starting_points=np.array([[0,0,1],[0,0,1],[0,0,1]])
ending_points=np.array([[n,0,1],[0,n,1],[0,0,0]])
U=ending_points[:,0]-starting_points[:,0]
V=ending_points[:,1]-starting_points[:,1]
W=ending_points[:,2]-starting_points[:,2]
ax.quiver(starting_points[:,0],starting_points[:,1],starting_points[:,2],U,V,W, color='k', arrow_length_ratio=0.0)

for i in range(13):
    ax.plot([0,n],[0,0],[i/13,i/13],c=colors[i],alpha=.4)

# Define the basis vectors


ax.xaxis.set_ticks_position('both')  # Show ticks on both sides of x-axis
ax.yaxis.set_ticks_position('both')  # Show ticks on both sides of y-axis
ax.zaxis.set_ticks_position('both') 
# ax.set_xscale('log')  # Set x-axis to logarithmic scale
# ax.set_yscale('log')

# Customize the plot
ax.yaxis.set_rotate_label(False)  # disable automatic rotation
ax.set_xlabel('O$_{spiral}$ ',fontsize=17,labelpad=20)
ax.set_ylabel('O$_{ring}$',fontsize=17,rotation=0,labelpad=12)
# ax3.set_zlabel('Energy Ratio',fontsize=18)
ax.tick_params(labelsize=14)
ax.set_xlim(0,n)
ax.set_ylim(0,n)
ax.set_zlim(0,1)
ax.set_xticks([0,.1,.2])
ax.set_yticks([0,.1,.2])
ax.set_zticks([0,1])
ax.set_title('d) Disorder of Spiral$_c$ vs Ring Planes$_{ab}$',fontsize=17,pad=-80)

ax.invert_zaxis()
ax.view_init(elev=11,azim=0,vertical_axis='y')

ax.set_box_aspect([1, 1, .5])


#####################################


plt.rcParams['font.family']='serif'

plt.rcParams['font.serif']='Times New Roman'



plt.tight_layout()

plt.savefig('3d_patch_waterfall.png',dpi=300,bbox_inches='tight')
plt.show()
